# %%
import pandas
import sqlite3

connection=sqlite3.connect('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/NASDAQ')

# %%
import pandas
import sqlite3

connection=sqlite3.connect('C:/sers/ltorrado/Desktop/Apps/Finanzas/app_finance/NASDAQ')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-b927307af243> in <module>
#       2 import sqlite3
#       3
# ----> 4 connection=sqlite3.connect('C:/sers/ltorrado/Desktop/Apps/Finanzas/app_finance/NASDAQ')
#
# OperationalError: unable to open database file

# %%
clear()

# %%
import pandas as pd
import sqlite3

connection=sqlite3.connect('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/NASDAQ')
df=pd.read_sql('SELECT * FROM OVERVIEW_NASDAQ ',connection)
connection.close()
df
# Out:
#      SYMBOL    ASSET_TYPE                             NAME  \
# 0       AAL  Common Stock      American Airlines Group Inc
# 1      AAME  Common Stock    Atlantic American Corporation
# 2      AAOI  Common Stock     Applied Optoelectronics, Inc
# 3      AAON  Common Stock                        AAON, Inc
# 4      AAPL  Common Stock                        Apple Inc
# ...     ...           ...                              ...
# 1230     KE  Common Stock         Kimball Electronics, Inc
# 1231  KELYA  Common Stock              Kelly Services, Inc
# 1232  KELYB  Common Stock              Kelly Services, Inc
# 1233   KEQU  Common Stock  Kewaunee Scientific Corporation
# 1234   KERX  Common Stock    Keryx Biopharmaceuticals, Inc
#
#                                             DESCRIPTION EXCHANGE CURRENCY  \
# 0     American Airlines Group Inc., through its subs...   NASDAQ      USD
# 1     Atlantic American Corporation, through its sub...   NASDAQ      USD
# ...

# %%
print(df.columns)
# Out:
# Index(['SYMBOL', 'ASSET_TYPE', 'NAME', 'DESCRIPTION', 'EXCHANGE', 'CURRENCY',
#        'COUNTRY', 'SECTOR', 'INDUSTRY', 'ADDRESS', 'FULLTIMEEMPLOYEES',
#        'FISCALYEAREND', 'LATESTQUARTER', 'MARKETCAPITALIZATION', 'EBITDA',
#        'PER_RATIO', 'PEG_RATIO', 'BOOKVALUE', 'DIVIDEND_PER_SHARE',
#        'DIVIDEND_YIELD', 'EPS', 'REVENUE_PER_SHARE_TTM', 'PROFIT_MARGIN',
#        'OPERATING_MARGIN_TTM', 'RETURN_ON_ASSET_TTM', 'RETURN_ON_EQUITY_TTM',
#        'REVENUE_TTM', 'GROSSPROFIT_TTM', 'DILUTED_EPS_TTM',
#        'QUARTERLY_EARNINGS_GROWTH_YOY', 'QUARTERLY_RENEVUE_GROWTH_YOY',
#        'ANALYST_TARGET_PRICE', 'TRAILING_PE', 'FOWARD_PE',
#        'PRICE_TO_SALE_RATIO_TTM', 'PRICE_TO_BOOK_RATIO', 'EV_TO_REVENUE',
#        'EV_TO_EBITDA', 'BETA', 'C52WEEKHIGH', 'C52WEEKLOW',
#        'C50DAYMOVINGAVERAGE', 'C200DAYMOVINGAVERAGE', 'SHARES_OUTSTANDING',
#        'SHARES_FLOAT', 'SHARES_SHORT', 'SHARES_SHORTPRIORMONTH', 'SHORT_RATIO',
# ...

# %%
df.groupby(['SECTOR']).mean().sort_values()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-6-4a2663e0b7fb> in <module>
# ----> 1 df.groupby(['SECTOR']).mean().sort_values()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1230         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
#    1231         return self._cython_agg_general(
# -> 1232             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1233         )
#    1234
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1002     ) -> DataFrame:
#    1003         agg_blocks, agg_items = self._cython_agg_blocks(
# -> 1004             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1005         )
# ...

# %%
df.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-b1a68fcb0857> in <module>
# ----> 1 df.type()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
df.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-144c7b0decef> in <module>
# ----> 1 df.dtype()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-b959c06452a1> in <module>
# ----> 1 df.dtype
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.dtypes
# Out:
# SYMBOL                           object
# ASSET_TYPE                       object
# NAME                             object
# DESCRIPTION                      object
# EXCHANGE                         object
# CURRENCY                         object
# COUNTRY                          object
# SECTOR                           object
# INDUSTRY                         object
# ADDRESS                          object
# FULLTIMEEMPLOYEES                object
# FISCALYEAREND                    object
# LATESTQUARTER                    object
# MARKETCAPITALIZATION             object
# EBITDA                           object
# PER_RATIO                        object
# PEG_RATIO                        object
# BOOKVALUE                        object
# DIVIDEND_PER_SHARE               object
# DIVIDEND_YIELD                   object
# EPS                              object
# REVENUE_PER_SHARE_TTM            object
# PROFIT_MARGIN                    object
# ...

# %%
df['SHARES_SHORT'] = df['SHARES_SHORT'].astype(float)
df.dtypes
# Out:
# SYMBOL                            object
# ASSET_TYPE                        object
# NAME                              object
# DESCRIPTION                       object
# EXCHANGE                          object
# CURRENCY                          object
# COUNTRY                           object
# SECTOR                            object
# INDUSTRY                          object
# ADDRESS                           object
# FULLTIMEEMPLOYEES                 object
# FISCALYEAREND                     object
# LATESTQUARTER                     object
# MARKETCAPITALIZATION              object
# EBITDA                            object
# PER_RATIO                         object
# PEG_RATIO                         object
# BOOKVALUE                         object
# DIVIDEND_PER_SHARE                object
# DIVIDEND_YIELD                    object
# EPS                               object
# REVENUE_PER_SHARE_TTM             object
# PROFIT_MARGIN                     object
# ...

# %%
df.groupby(['SECTOR']).mean().sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4a2663e0b7fb> in <module>
# ----> 1 df.groupby(['SECTOR']).mean().sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
df.groupby(['SECTOR']).mean()
# Out:
#                         SHARES_SHORT
# SECTOR
#                         1.730100e+04
# Basic Materials         3.412301e+06
# Communication Services  8.629061e+06
# Consumer Cyclical       5.642276e+06
# Consumer Defensive      1.657237e+06
# Energy                  2.996618e+06
# Financial Services      1.302041e+06
# Healthcare              5.861271e+06
# Industrials             3.646005e+06
# Other                   1.190941e+05
# Real Estate             1.780642e+06
# Services                4.871730e+05
# Technology              4.323180e+06
# Utilities               8.023715e+05

# %%
df['PROFIT_MARGIN'] = df['PROFIT_MARGIN'].astype(float)
df.dtypes
# Out:
# SYMBOL                            object
# ASSET_TYPE                        object
# NAME                              object
# DESCRIPTION                       object
# EXCHANGE                          object
# CURRENCY                          object
# COUNTRY                           object
# SECTOR                            object
# INDUSTRY                          object
# ADDRESS                           object
# FULLTIMEEMPLOYEES                 object
# FISCALYEAREND                     object
# LATESTQUARTER                     object
# MARKETCAPITALIZATION              object
# EBITDA                            object
# PER_RATIO                         object
# PEG_RATIO                         object
# BOOKVALUE                         object
# DIVIDEND_PER_SHARE                object
# DIVIDEND_YIELD                    object
# EPS                               object
# REVENUE_PER_SHARE_TTM             object
# PROFIT_MARGIN                    float64
# ...

# %%
df.groupby(['SECTOR']).mean()
# Out:
#                         PROFIT_MARGIN  SHARES_SHORT
# SECTOR
#                              0.000000  1.730100e+04
# Basic Materials             -0.461327  3.412301e+06
# Communication Services      -0.019633  8.629061e+06
# Consumer Cyclical           -0.031628  5.642276e+06
# Consumer Defensive           0.011503  1.657237e+06
# Energy                      -0.150478  2.996618e+06
# Financial Services           0.137312  1.302041e+06
# Healthcare                  -0.259655  5.861271e+06
# Industrials                 -0.033845  3.646005e+06
# Other                        0.000283  1.190941e+05
# Real Estate                  0.009453  1.780642e+06
# Services                     0.002100  4.871730e+05
# Technology                  -0.009049  4.323180e+06
# Utilities                    0.065500  8.023715e+05

# %%
    df.to_csv(r'C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/NASDAQ_1.csv', index = False)

# %%
df.read_csv('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/NASDAQ_1.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-dc3036f7a5fe> in <module>
# ----> 1 df.read_csv('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/NASDAQ_1.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'read_csv'

# %%
df1=pd.read_csv('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/NASDAQ_1.csv')

# %%
print(df1)
# Out:
#      SYMBOL    ASSET_TYPE                             NAME  \
# 0       AAL  Common Stock      American Airlines Group Inc
# 1      AAME  Common Stock    Atlantic American Corporation
# 2      AAOI  Common Stock     Applied Optoelectronics, Inc
# 3      AAON  Common Stock                        AAON, Inc
# 4      AAPL  Common Stock                        Apple Inc
# ...     ...           ...                              ...
# 1230     KE  Common Stock         Kimball Electronics, Inc
# 1231  KELYA  Common Stock              Kelly Services, Inc
# 1232  KELYB  Common Stock              Kelly Services, Inc
# 1233   KEQU  Common Stock  Kewaunee Scientific Corporation
# 1234   KERX  Common Stock    Keryx Biopharmaceuticals, Inc
#
#                                             DESCRIPTION EXCHANGE CURRENCY  \
# 0     American Airlines Group Inc., through its subs...   NASDAQ      USD
# 1     Atlantic American Corporation, through its sub...   NASDAQ      USD
# ...

# %%
df1.dtypes
# Out:
# SYMBOL                            object
# ASSET_TYPE                        object
# NAME                              object
# DESCRIPTION                       object
# EXCHANGE                          object
# CURRENCY                          object
# COUNTRY                           object
# SECTOR                            object
# INDUSTRY                          object
# ADDRESS                           object
# FULLTIMEEMPLOYEES                 object
# FISCALYEAREND                     object
# LATESTQUARTER                     object
# MARKETCAPITALIZATION              object
# EBITDA                            object
# PER_RATIO                         object
# PEG_RATIO                         object
# BOOKVALUE                         object
# DIVIDEND_PER_SHARE                object
# DIVIDEND_YIELD                    object
# EPS                               object
# REVENUE_PER_SHARE_TTM            float64
# PROFIT_MARGIN                    float64
# ...

# %%
connection=sqlite3.connect('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/SP500')
df=pd.read_sql('SELECT * FROM OVERVIEW_SP500 ',connection)
connection.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3e4edcb94bb7> in <module>
# ----> 1 connection=sqlite3.connect('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/SP500')
#       2 df=pd.read_sql('SELECT * FROM OVERVIEW_SP500 ',connection)
#       3 connection.close()
#
# NameError: name 'sqlite3' is not defined

# %%
import pandas as pd
import sqlite3

connection=sqlite3.connect('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/SP500')
df_sp500=pd.read_sql('SELECT * FROM OVERVIEW_SP500 ',connection)
connection.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1585         try:
# -> 1586             cur.execute(*args, **kwargs)
#    1587             return cur
#
# OperationalError: no such table: OVERVIEW_SP500
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-2-9f3d0ffa1da3> in <module>
#       3
#       4 connection=sqlite3.connect('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/SP500')
# ----> 5 df_sp500=pd.read_sql('SELECT * FROM OVERVIEW_SP500 ',connection)
#       6 connection.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
# ...

# %%
connection=sqlite3.connect('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/OVERVIEW_SP500')
df=pd.read_sql('SELECT * FROM OVERVIEW_SP500 ',connection)
connection.close()

# %%
df.dftypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-a5560dd47c72> in <module>
# ----> 1 df.dftypes
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dftypes'

# %%
df.dtypes
# Out:
# SYMBOL                           object
# ASSET_TYPE                       object
# NAME                             object
# DESCRIPTION                      object
# EXCHANGE                         object
# CURRENCY                         object
# COUNTRY                          object
# SECTOR                           object
# INDUSTRY                         object
# ADDRESS                          object
# FULLTIMEEMPLOYEES                object
# FISCALYEAREND                    object
# LATESTQUARTER                    object
# MARKETCAPITALIZATION             object
# EBITDA                           object
# PER_RATIO                        object
# PEG_RATIO                        object
# BOOKVALUE                        object
# DIVIDEND_PER_SHARE               object
# DIVIDEND_YIELD                   object
# EPS                              object
# REVENUE_PER_SHARE_TTM            object
# PROFIT_MARGIN                    object
# ...

# %%
df.read_csv('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/SP500_1.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-edc6f02fdc77> in <module>
# ----> 1 df.read_csv('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/SP500_1.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'read_csv'

# %%
df.head()
# Out:
#   SYMBOL    ASSET_TYPE                         NAME  \
# 0    MMM  Common Stock                   3M Company
# 1    AOS  Common Stock      A. O. Smith Corporation
# 2    ALK  Common Stock        Alaska Air Group, Inc
# 3   ALLE  Common Stock                 Allegion plc
# 4    AAL  Common Stock  American Airlines Group Inc
#
#                                          DESCRIPTION EXCHANGE CURRENCY  \
# 0  3M Company develops, manufactures, and markets...     NYSE      USD
# 1  A. O. Smith Corporation manufactures and marke...     NYSE      USD
# 2  Alaska Air Group, Inc., through its subsidiari...     NYSE      USD
# 3  Allegion plc manufactures and sells mechanical...     NYSE      USD
# 4  American Airlines Group Inc., through its subs...   NASDAQ      USD
#
#   COUNTRY       SECTOR                        INDUSTRY  \
# 0     USA  Industrials  Specialty Industrial Machinery
# 1     USA  Industrials  Specialty Industrial Machinery
# ...

# %%
df.to_csv(r'C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/SP500_OVERVIEW.csv', index = False)

# %%
df=pd.read_csv('C:/Users/ltorrado/Desktop/Apps/Finanzas/app_finance/NASDAQ_1.csv')

# %%
df.dtypes
# Out:
# SYMBOL                            object
# ASSET_TYPE                        object
# NAME                              object
# DESCRIPTION                       object
# EXCHANGE                          object
# CURRENCY                          object
# COUNTRY                           object
# SECTOR                            object
# INDUSTRY                          object
# ADDRESS                           object
# FULLTIMEEMPLOYEES                 object
# FISCALYEAREND                     object
# LATESTQUARTER                     object
# MARKETCAPITALIZATION              object
# EBITDA                            object
# PER_RATIO                         object
# PEG_RATIO                         object
# BOOKVALUE                         object
# DIVIDEND_PER_SHARE                object
# DIVIDEND_YIELD                    object
# EPS                               object
# REVENUE_PER_SHARE_TTM            float64
# PROFIT_MARGIN                    float64
# ...

# %%
df.groupby(['SECTOR']).describe()
# Out:
#                        REVENUE_PER_SHARE_TTM                                 \
#                                        count       mean         std     min
# SECTOR
# Basic Materials                         15.0  22.921600   28.368642   0.000
# Communication Services                  46.0  31.993717   57.920648   0.000
# Consumer Cyclical                       67.0  44.888448   82.903867   0.000
# Consumer Defensive                      32.0  80.731562  123.286174   0.000
# Energy                                  18.0  10.102389    8.943285   0.464
# Financial Services                     189.0  30.584741  201.282147   0.000
# Healthcare                             181.0   8.065895   14.888941   0.000
# Industrials                            103.0  32.972291   34.219301   0.000
# Other                                  423.0   0.022234    0.351430   0.000
# Real Estate                             15.0  10.020400   18.510596  -1.091
# ...

# %%
df.groupby(['SECTOR']).describe(['PROFIT_MARGIN'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-d5ae0619ccc4> in <module>
# ----> 1 df.groupby(['SECTOR']).describe(['PROFIT_MARGIN'])
#
# TypeError: describe() takes 1 positional argument but 2 were given

# %%
df.groupby(['SECTOR','PROFIT_MARGIN']).describe()
# Out:
#                               REVENUE_PER_SHARE_TTM                            \
#                                               count    mean       std     min
# SECTOR          PROFIT_MARGIN
# Basic Materials -2.5011                         1.0   0.935       NaN   0.935
#                 -2.4788                         1.0   1.100       NaN   1.100
#                 -1.7253                         1.0   1.268       NaN   1.268
#                 -0.4353                         1.0   0.000       NaN   0.000
#                 -0.2040                         1.0   8.742       NaN   8.742
# ...                                             ...     ...       ...     ...
# Technology       0.4692                         1.0   4.372       NaN   4.372
#                  0.5271                         1.0  11.621       NaN  11.621
# Utilities        0.0000                         2.0   0.006  0.014142  -0.004
#                  0.0719                         1.0   4.864       NaN   4.864
# ...

# %%
df.groupby(['SECTOR']).column(['PROFIT_MARGIN']).describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-7ac03e2c8ba2> in <module>
# ----> 1 df.groupby(['SECTOR']).column(['PROFIT_MARGIN']).describe()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'column'

# %%
df.column(['PROFIT_MARGIN'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-1f2b2c41b673> in <module>
# ----> 1 df.column(['PROFIT_MARGIN'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
df['PROFIT_MARGIN'].groupby(['SECTOR']).describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-e6da0167627e> in <module>
# ----> 1 df['PROFIT_MARGIN'].groupby(['SECTOR']).describe()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    1685             group_keys=group_keys,
#    1686             squeeze=squeeze,
# -> 1687             observed=observed,
#    1688         )
#    1689
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# ...

# %%
df['PROFIT_MARGIN']
# Out:
# 0      -0.1040
# 1      -0.0089
# 2      -0.3972
# 3       0.1427
# 4       0.2133
#          ...
# 1230    0.0152
# 1231   -0.0218
# 1232   -0.0218
# 1233   -0.0318
# 1234    0.0000
# Name: PROFIT_MARGIN, Length: 1235, dtype: float64

# %%
df['PROFIT_MARGIN','SECTOR']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('PROFIT_MARGIN', 'SECTOR')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-637030d5a405> in <module>
# ...

# %%
df['PROFIT_MARGIN']['SECTOR']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-d9f8e3a2158e> in <module>
# ----> 1 df['PROFIT_MARGIN']['SECTOR']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...
